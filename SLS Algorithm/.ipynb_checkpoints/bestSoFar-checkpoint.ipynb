# %%
import pandas as pd

# %%
#best so far

import numpy as np
import random
import math
import os
import time

def read_tsp_file(filename):
    """
    Read TSP file and extract information.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()
        num_locations = int(lines[0].strip())
        adjacency_matrix = np.zeros((num_locations, num_locations))
        for i in range(num_locations):
            distances = list(map(float, lines[i + 1].strip().split()))
            adjacency_matrix[i] = distances
    return num_locations, adjacency_matrix

def distance(city1, city2):
    """
    Calculate Euclidean distance between two cities.
    """
    return np.linalg.norm(city1 - city2)

def total_distance(cities_order, distances):
    """
    Calculate the total distance of the path.
    """
    total = 0
    num_cities = len(cities_order)
    for i in range(num_cities - 1):
        total += distances[cities_order[i], cities_order[i + 1]]
    total += distances[cities_order[-1], cities_order[0]]  # Return to the starting city
    return total

def two_opt_swap(route, i, j):
    """
    Perform a 2-opt swap on the route.
    """
    new_route = route[:i] + route[i:j+1][::-1] + route[j+1:]
    return new_route

def nearest_neighbor_heuristic(distances):
    """
    Initialize the solution using the nearest neighbor heuristic.
    """
    num_cities = len(distances)
    current_city = random.randint(0, num_cities - 1)
    unvisited_cities = set(range(num_cities))
    unvisited_cities.remove(current_city)
    route = [current_city]

    while unvisited_cities:
        nearest_city = min(unvisited_cities, key=lambda city: distances[current_city][city])
        route.append(nearest_city)
        unvisited_cities.remove(nearest_city)
        current_city = nearest_city

    return route

def simulated_annealing(adjacency_matrix, initial_temperature=10000, stopping_temperature=1e-6, num_iterations=10000):
    """
    Solve TSP using Simulated Annealing algorithm with 2-opt.
    """
    num_cities = len(adjacency_matrix)

    current_order = nearest_neighbor_heuristic(adjacency_matrix)
    current_cost = total_distance(current_order, adjacency_matrix)

    best_order = current_order.copy()
    best_cost = current_cost

    temperature = initial_temperature
    iteration = 0

    while temperature > stopping_temperature and iteration < num_iterations:
        # Generate a new solution
        i, j = sorted(random.sample(range(num_cities), 2))
        new_order = two_opt_swap(current_order, i, j)
        new_cost = total_distance(new_order, adjacency_matrix)

        # Acceptance probability based on new and current costs
        delta_cost = new_cost - current_cost
        if delta_cost < 0 or random.random() < math.exp(-delta_cost / temperature):
            current_order = new_order
            current_cost = new_cost

        # Keep track of the best solution found so far
        if current_cost < best_cost:
            best_order = current_order.copy()
            best_cost = current_cost

        # Cooling schedule: geometric cooling
        temperature *= 0.995
        iteration += 1

    return best_order, best_cost, total_distance(best_order, adjacency_matrix)


if __name__ == "__main__":
    folder_path = "/home/sgilango/Traveling-Salesman-Problem---AI/TestRuns/"
    file_name = "tsp-problem-100-100-100-25-1.txt"  # Example file name
    file_path = os.path.join(folder_path, file_name)

    num_locations, adjacency_matrix = read_tsp_file(file_path)

    start_time = time.time()
    best_order, best_cost, total_dist = simulated_annealing(adjacency_matrix)
    end_time = time.time()

    print("Best order:", best_order)
    print("Best cost:", best_cost)
    print("Total distance traveled:", total_dist)
    print("Execution time:", end_time - start_time, "seconds")
# Out:
# Best order: [11, 64, 31, 90, 54, 12, 48, 60, 1, 26, 69, 92, 45, 93, 84, 77, 15, 49, 0, 55, 73, 30, 46, 3, 86, 13, 67, 80, 47, 65, 32, 87, 50, 66, 23, 59, 8, 9, 63, 88, 89, 7, 40, 68, 52, 43, 16, 44, 71, 10, 21, 82, 41, 17, 5, 28, 81, 58, 2, 53, 39, 37, 25, 83, 70, 42, 35, 74, 27, 14, 78, 62, 51, 97, 24, 91, 38, 95, 22, 33, 99, 94, 61, 96, 98, 75, 20, 6, 56, 72, 85, 4, 76, 19, 79, 36, 18, 29, 34, 57]
# Best cost: 4395.433655108736
# Total distance traveled: 4395.433655108736
# Execution time: 0.3164374828338623 seconds

# %%
#version2

# %%
#Competition

# %%
def solve_tsp_files(folder_path):
    """
    Solve TSP for all .txt files in the given folder.
    """
    results = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".txt"):
            file_path = os.path.join(folder_path, file_name)
            print(file_path)
            num_locations, adjacency_matrix = read_tsp_file(file_path)
            start_time = time.time()
            best_order, best_cost, total_dist = simulated_annealing(adjacency_matrix)
            end_time = time.time()
            execution_time = end_time - start_time
            results.append([file_name, best_order, best_cost, execution_time])
    return results

# %%
folder_path = "/home/sgilango/Traveling-Salesman-Problem---AI/TestRuns"  # Adjust folder path as needed

results = solve_tsp_files(folder_path)

# %%
df = pd.DataFrame(results, columns=['Input', 'Route', 'Best Distance', 'Time'])
print(df)
df.to_csv("results.csv")
# Out:
#                                 Input  \
# 0    tsp-problem-800-100-150-45-1.txt
# 1   tsp-problem-500-1000-150-35-1.txt
# 2     tsp-problem-700-500-50-25-1.txt
# 3    tsp-problem-1000-1000-50-5-1.txt
# 4    tsp-problem-500-1000-100-5-1.txt
# 5   tsp-problem-300-1000-150-45-1.txt
# 6    tsp-problem-500-100-100-25-1.txt
# 7   tsp-problem-400-5000-100-45-1.txt
# 8    tsp-problem-900-1000-50-25-1.txt
# 9    tsp-problem-200-1000-50-25-1.txt
# 10   tsp-problem-100-100-100-25-1.txt
# 11    tsp-problem-100-100-100-5-1.txt
#
#                                                 Route  Best Distance      Time
# 0   [283, 164, 9, 49, 43, 71, 168, 106, 36, 247, 8...   32445.700291  2.241399
# 1   [485, 470, 154, 497, 26, 134, 7, 304, 120, 77,...   24417.977570  1.338234
# 2   [676, 49, 235, 652, 23, 480, 34, 680, 378, 131...    2023.836259  1.910503
# 3   [574, 266, 495, 329, 924, 298, 420, 866, 150, ...   37718.558381  2.845835
# 4   [74, 202, 337, 158, 107, 79, 15, 479, 413, 159...   44047.681724  1.337732
# 5   [9, 107, 180, 98, 242, 4, 229, 289, 281, 158, ...   11375.034658  0.817271
# 6   [109, 437, 267, 30, 8, 155, 245, 44, 183, 2, 2...   23591.379667  1.341975
# 7   [323, 344, 2, 128, 86, 40, 238, 329, 236, 186,...    3018.967933  1.062032
# 8   [138, 332, 229, 344, 55, 429, 378, 468, 22, 56...    1604.306875  2.519117
# 9   [154, 81, 123, 142, 0, 46, 195, 53, 57, 10, 99...     902.795491  0.539497
# 10  [75, 20, 10, 71, 44, 16, 43, 52, 82, 26, 1, 60...    4503.803780  0.301731
# 11  [68, 26, 37, 45, 34, 9, 55, 53, 32, 39, 42, 8,...    8954.988431  0.295542

# %%
#plots

import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
data = pd.read_csv("results.csv")

# Solution Quality Boxplot
plt.figure(figsize=(10, 6))
data.boxplot(column='Best Distance', by='Input', grid=False)
plt.xlabel('TSP instances or parameter settings')
plt.ylabel('Total distance of the best solution')
plt.title('Solution Quality Boxplot')
plt.show()

# Execution Time Boxplot
plt.figure(figsize=(10, 6))
data.boxplot(column='Time', by='Input', grid=False)
plt.xlabel('TSP instances or parameter settings')
plt.ylabel('Execution time')
plt.title('Execution Time Boxplot')
plt.show()

# Scalability Analysis
plt.figure(figsize=(10, 6))
plt.plot(data['Input'], data['Time'], marker='o', linestyle='-')
plt.xlabel('Number of cities in the TSP instance')
plt.ylabel('Execution time')
plt.title('Scalability Analysis')
plt.grid(True)
plt.show()

# %%
#part 2 plots

# %%
#1---------Convergence

import numpy as np
import random
import math
import os
import time
import matplotlib.pyplot as plt

# Your existing functions go here...

def simulated_annealing(adjacency_matrix, initial_temperature=10, stopping_temperature=1e-3, num_iterations=10000, cooling_rate=0.995):
    """
    Solve TSP using Simulated Annealing algorithm with 2-opt.
    """
    num_cities = len(adjacency_matrix)

    current_order = nearest_neighbor_heuristic(adjacency_matrix)
    current_cost = total_distance(current_order, adjacency_matrix)

    best_order = current_order.copy()
    best_cost = current_cost

    temperature = initial_temperature
    iteration = 0

    costs = []  # List to store the best cost at each iteration

    while temperature > stopping_temperature and iteration < num_iterations:
        # Generate a new solution
        i, j = sorted(random.sample(range(num_cities), 2))
        new_order = two_opt_swap(current_order, i, j)
        new_cost = total_distance(new_order, adjacency_matrix)

        # Acceptance probability based on new and current costs
        delta_cost = new_cost - current_cost
        if delta_cost < 0 or random.random() < math.exp(-delta_cost / temperature):
            current_order = new_order
            current_cost = new_cost

        # Keep track of the best solution found so far
        if current_cost < best_cost:
            best_order = current_order.copy()
            best_cost = current_cost

        # Store the best cost at each iteration
        costs.append(best_cost)

        # Cooling schedule: geometric cooling
        temperature *= cooling_rate
        iteration += 1

    return best_order, best_cost, costs

if __name__ == "__main__":
    # Example file path
    folder_path = "/home/sgilango/Traveling-Salesman-Problem---AI/TestRuns/"
    file_name = "tsp-problem-100-100-100-25-1.txt"
    file_path = os.path.join(folder_path, file_name)

    num_locations, adjacency_matrix = read_tsp_file(file_path)

    start_time = time.time()
    best_order, best_cost, costs = simulated_annealing(adjacency_matrix)
    end_time = time.time()

    print("Best cost:", best_cost)
    print("Total distance traveled:", total_distance(best_order, adjacency_matrix))
    print("Execution time:", end_time - start_time, "seconds")

    # Plot convergence
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(costs)), costs, label='Simulated Annealing')
    plt.xlabel('Iteration')
    plt.ylabel('Cost')
    plt.title('Convergence of Simulated Annealing')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Best cost: 4451.576549481715
# Total distance traveled: 4451.576549481715
# Execution time: 0.12775063514709473 seconds

# %%
import numpy as np
import random
import math
import os
import time
import matplotlib.pyplot as plt

def read_tsp_file(filename):
    """
    Read TSP file and extract information.
    """
    with open(filename, 'r') as file:
        lines = file.readlines()
        num_locations = int(lines[0].strip())
        adjacency_matrix = np.zeros((num_locations, num_locations))
        for i in range(num_locations):
            distances = list(map(float, lines[i + 1].strip().split()))
            adjacency_matrix[i] = distances
    return num_locations, adjacency_matrix

def distance(city1, city2):
    """
    Calculate Euclidean distance between two cities.
    """
    return np.linalg.norm(city1 - city2)

def total_distance(cities_order, distances):
    """
    Calculate the total distance of the path.
    """
    total = 0
    num_cities = len(cities_order)
    for i in range(num_cities - 1):
        total += distances[cities_order[i], cities_order[i + 1]]
    total += distances[cities_order[-1], cities_order[0]]  # Return to the starting city
    return total

def two_opt_swap(route, i, j):
    """
    Perform a 2-opt swap on the route.
    """
    new_route = route[:i] + route[i:j+1][::-1] + route[j+1:]
    return new_route

def nearest_neighbor_heuristic(distances):
    """
    Initialize the solution using the nearest neighbor heuristic.
    """
    num_cities = len(distances)
    current_city = random.randint(0, num_cities - 1)
    unvisited_cities = set(range(num_cities))
    unvisited_cities.remove(current_city)
    route = [current_city]

    while unvisited_cities:
        nearest_city = min(unvisited_cities, key=lambda city: distances[current_city][city])
        route.append(nearest_city)
        unvisited_cities.remove(nearest_city)
        current_city = nearest_city

    return route

def simulated_annealing(adjacency_matrix, initial_temperature=10, stopping_temperature=1e-3, num_iterations=10000):
    """
    Solve TSP using Simulated Annealing algorithm with 2-opt.
    """
    num_cities = len(adjacency_matrix)

    current_order = nearest_neighbor_heuristic(adjacency_matrix)
    current_cost = total_distance(current_order, adjacency_matrix)

    best_order = current_order.copy()
    best_cost = current_cost

    temperature = initial_temperature
    iteration = 0

    iteration_data = []  # Store iteration number
    cost_data = []       # Store best cost found so far
    temperature_data = [] # Store temperature at each iteration

    while temperature > stopping_temperature and iteration < num_iterations:
        # Generate a new solution
        i, j = sorted(random.sample(range(num_cities), 2))
        new_order = two_opt_swap(current_order, i, j)
        new_cost = total_distance(new_order, adjacency_matrix)

        # Acceptance probability based on new and current costs
        delta_cost = new_cost - current_cost
        if delta_cost < 0 or random.random() < math.exp(-delta_cost / temperature):
            current_order = new_order
            current_cost = new_cost

        # Keep track of the best solution found so far
        if current_cost < best_cost:
            best_order = current_order.copy()
            best_cost = current_cost

        # Cooling schedule: geometric cooling
        temperature *= 0.995
        iteration += 1

        # Store data for plotting
        iteration_data.append(iteration)
        cost_data.append(best_cost)
        temperature_data.append(temperature)

    return best_order, best_cost, total_distance(best_order, adjacency_matrix), iteration_data, cost_data, temperature_data

if __name__ == "__main__":
    folder_path = "/home/sgilango/Traveling-Salesman-Problem---AI/TestRuns/"
    file_name = "tsp-problem-100-100-100-25-1.txt"  # Example file name
    file_path = os.path.join(folder_path, file_name)

    num_locations, adjacency_matrix = read_tsp_file(file_path)

    start_time = time.time()
    best_order, best_cost, total_dist, iteration_data, cost_data, temperature_data = simulated_annealing(adjacency_matrix)
    end_time = time.time()

    print("Best order:", best_order)
    print("Best cost:", best_cost)
    print("Total distance traveled:", total_dist)
    print("Execution time:", end_time - start_time, "seconds")

    # Plotting
    plt.figure(figsize=(12, 6))

    # Plot cost vs. iteration
    plt.subplot(1, 2, 1)
    plt.plot(iteration_data, cost_data, color='b', marker='o', linestyle='-')
    plt.title('Cost vs. Iteration')
    plt.xlabel('Iteration')
    plt.ylabel('Cost')

    # Plot temperature vs. iteration
    plt.subplot(1, 2, 2)
    plt.plot(iteration_data, temperature_data, color='r', marker='o', linestyle='-')
    plt.title('Temperature vs. Iteration')
    plt.xlabel('Iteration')
    plt.ylabel('Temperature')

    plt.tight_layout()
    plt.show()
# Out:
# Best order: [26, 82, 11, 64, 96, 7, 40, 83, 39, 13, 67, 80, 47, 65, 32, 87, 50, 66, 23, 59, 8, 9, 63, 98, 94, 68, 76, 19, 79, 48, 12, 54, 84, 93, 18, 29, 92, 45, 90, 31, 81, 16, 43, 52, 57, 21, 10, 71, 44, 74, 27, 14, 78, 62, 51, 97, 24, 91, 38, 42, 35, 99, 5, 28, 60, 1, 72, 56, 34, 75, 20, 6, 70, 41, 17, 77, 15, 49, 0, 55, 73, 30, 58, 2, 53, 61, 37, 25, 95, 22, 33, 88, 89, 85, 4, 36, 86, 3, 46, 69]
# Best cost: 4409.435668683061
# Total distance traveled: 4409.435668683061
# Execution time: 0.13469314575195312 seconds

# %%
if __name__ == "__main__":
    # Existing code...

    # Run simulated annealing algorithm
    best_order, best_cost, total_dist, iteration_data, cost_data, temperature_data = simulated_annealing(adjacency_matrix)

    # Advanced Plotting
    plt.figure(figsize=(18, 12))

    # Trajectory Plot
    plt.subplot(2, 2, 1)
    plt.plot([adjacency_matrix[i][0] for i in best_order], [adjacency_matrix[i][1] for i in best_order], '-o')
    plt.title('Trajectory of the Algorithm')
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')

    # Fitness Landscape Visualization
    plt.subplot(2, 2, 4)
    fitness_landscape = np.zeros((100, 100))
    for i in range(100):
        for j in range(100):
            fitness_landscape[i][j] = total_distance([i, j], adjacency_matrix)
    plt.imshow(fitness_landscape, cmap='viridis', origin='lower')
    plt.colorbar(label='Cost')
    plt.title('Fitness Landscape Visualization')
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')

    plt.tight_layout()
    plt.show()
